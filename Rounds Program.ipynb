# %%
import os
import tkinter as tk
from tkinter import ttk
import librosa
import random
import numpy as np
import sounddevice as sd
import time

# %%
program = tk.Tk()
program.title("Automated Ballroom Rounds Generator")

style_label = ttk.Label(program, text="Which Style?")
styles = ["Standard", "Latin", "Smooth", "Rhythm", "Multi"]
style_menu = ttk.Combobox(program, values=styles)
style_menu.set("Select a Style")

level_label = ttk.Label(program, text="What Dregree of Insanity?")
level_menu = ttk.Combobox(program, values=[])
level_menu.set("Select Marathon Length")

style_menu.configure(width=50,height=10)
level_menu.configure(width=50,height=10)

playlist_label = ttk.Label(program, text="")
playlist_menu = ""

style_label.grid(row=1, column=1, columnspan=2)
style_menu.grid(row=2, column=1, columnspan=2)
level_label.grid(row=3, column=1, columnspan=2)
level_menu.grid(row=4, column=1, columnspan=2)

selected_style = ""

def style_select(style_menu):
    selected_style = style_menu.widget.get()
    if selected_style == "Standard":
        level_menu.config(values=["Novice", "Pre-Champ", "4-Dance", "Championship", "Waltz", "Tango", "Viennese Waltz", "Foxtrot", "Quickstep"])
    elif selected_style == "Latin":
        level_menu.config(values=["Novice", "Pre-Champ", "4-Dance (2-Phrase Paso)",  "4-Dance (3-Phrase Paso)", "Championship (2-Phrase Paso)", "Championship (3-Phrase Paso)", "Cha Cha", "Samba", "Rumba", "2-Phrased Paso Doble", "3-Phrased Paso Doble", "Jive"])
    elif selected_style == "Smooth":
        level_menu.config(values=["Novice", "Pre-Champ", "Championship", "Waltz", "Tango", "Foxtrot", "Viennese Waltz"])
    elif selected_style == "Rhythm":
        level_menu.config(values=["Novice (CC/M)", "Novice (Sw/M)", "Novice (B/M)", "Pre-Champ (CC/Sw/M)", "Pre-Champ (CC/B/M)", "Pre-Champ (Sw/B/M)",  "4-Dance (CC/Sw/B/M)", "Championship", "Cha Cha", "Rumba", "Swing", "Bolero", "Mambo"])
    elif selected_style == "Multi":
        level_menu.config(values=["Pre-Teen American (W/CC/F/Sw)", "American 9-Dance (W/T/F/VW/CC/R/Sw/B/M)", "International 10-Dance (W/T/VW/F/Q/CC/S/R/PD/J)"])
    else:
        level_menu.config(values=["Pick a Style"])

def level_select(level_menu):
    selected_level = level_menu.widget.get()

def kill_switch():
    sd.stop()
    pass

kill_button = tk.Button(program, text="Stop", command=kill_switch)
kill_button.configure(width=50, height=2)
kill_button.grid(row=7, column=1, columnspan=2)
style_menu.bind("<<ComboboxSelected>>", style_select)
level_menu.bind("<<ComboboxSelected>>", level_select)

silence_duration = 12.5
silence = np.zeros(int(silence_duration * 44100))

# %%
def create_round():
    selected_style = style_menu.get()
    selected_level = level_menu.get()
    if selected_style == "Standard":
        if selected_level == "Novice":
            waltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/NDCA Edits (87BPM)/'
            waltzes = [f for f in os.listdir(waltz_files) if f.endswith("flac")]
            waltz_song = random.choice(waltzes)
            quickstep_files = 'E:/Music/Incompressible Files/Edits/Quickstep/NDCA Edits (200BPM)/'
            quicksteps = [f for f in os.listdir(quickstep_files) if f.endswith("flac")]
            quickstep_song = random.choice(quicksteps)
            for i in range(heats):
                waltz, wsr = librosa.load(os.path.join(waltz_files, waltz_song), sr=None)
                fade_duration = 10
                fade_samples = int(fade_duration * wsr)
                fade_env = np.linspace(1, 0, fade_samples)
                fade_start_point_waltz = int((random.randint(7000,8000)/1000) * wsr)
                fade_end_point_waltz = int(fade_start_point_waltz + (fade_duration * wsr))
                waltz_faded = waltz[0:fade_end_point_waltz].copy()
                for i in range(fade_start_point_waltz,fade_end_point_waltz):
                    waltz_faded[i] = waltz[i] * fade_env[i-fade_start_point_waltz]
                sd.play(waltz_faded, wsr)
                sd.wait()
                sd.play(silence, silence_sample_rate)
                sd.wait()
                
                        
            for i in range(heats):
                quickstep, qsr = librosa.load(os.path.join(quickstep_files, quickstep_song), sr=None)
                fade_duration = 10
                fade_samples = int(fade_duration * qsr)
                fade_env = np.linspace(1, 0, fade_samples)
                fade_start_point_quickstep = int((random.randint(7000,8000)/1000) * qsr)
                fade_end_point_quickstep = int(fade_start_point_quickstep + (fade_duration * qsr))
                quickstep_faded = quickstep[0:fade_end_point_quickstep].copy()
                for i in range(fade_start_point_quickstep,fade_end_point_quickstep):
                    quickstep_faded[i] = quickstep[i] * fade_env[i-fade_start_point_quickstep]
                sd.play(quickstep_faded, qsr)
                sd.wait()
                sd.play(silence, silence_sample_rate)
                sd.wait()    
        elif selected_level == "Pre-Champ":
            waltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/NDCA Edits (87BPM)/'
            waltzes = [f for f in os.listdir(waltz_files) if f.endswith("flac")]
            waltz_song = random.choice(waltzes)
            waltz, sr = librosa.load(os.path.join(waltz_files, waltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_waltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_waltz = int(fade_start_point_waltz + (fade_duration * sr))
            waltz_faded = waltz[0:fade_end_point_waltz].copy()
            for i in range(fade_start_point_waltz,fade_end_point_waltz):
                waltz_faded[i] = waltz[i] * fade_env[i-fade_start_point_waltz]
                
            tango_files = 'E:/Music/Incompressible Files/Edits/Tango/NDCA Edits (128BPM)/'
            tangos = [f for f in os.listdir(tango_files) if f.endswith("flac")]
            tango_song = random.choice(tangos)
            tango, sr = librosa.load(os.path.join(tango_files, tango_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_tango = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_tango = int(fade_start_point_tango + (fade_duration * sr))
            tango_faded = tango[0:fade_end_point_tango].copy()
            for i in range(fade_start_point_tango,fade_end_point_tango):
                tango_faded[i] = tango[i] * fade_env[i-fade_start_point_tango]
            
            quickstep_files = 'E:/Music/Incompressible Files/Edits/Quickstep/NDCA Edits (200BPM)/'
            quicksteps = [f for f in os.listdir(quickstep_files) if f.endswith("flac")]
            quickstep_song = random.choice(quicksteps)
            quickstep, sr = librosa.load(os.path.join(quickstep_files, quickstep_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_quickstep = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_quickstep = int(fade_start_point_quickstep + (fade_duration * sr))
            quickstep_faded = quickstep[0:fade_end_point_quickstep].copy()
            for i in range(fade_start_point_quickstep,fade_end_point_quickstep):
                quickstep_faded[i] = quickstep[i] * fade_env[i-fade_start_point_quickstep]
            
            sd.stop()
            prechamp_standard = np.concatenate([waltz_faded, silence, tango_faded, silence, quickstep_faded])
            sd.play(prechamp_standard, samplerate=sr)
        elif selected_level == "4-Dance":
            waltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/NDCA Edits (87BPM)/'
            waltzes = [f for f in os.listdir(waltz_files) if f.endswith("flac")]
            waltz_song = random.choice(waltzes)
            waltz, sr = librosa.load(os.path.join(waltz_files, waltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_waltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_waltz = int(fade_start_point_waltz + (fade_duration * sr))
            waltz_faded = waltz[0:fade_end_point_waltz].copy()
            for i in range(fade_start_point_waltz,fade_end_point_waltz):
                waltz_faded[i] = waltz[i] * fade_env[i-fade_start_point_waltz]
                
            tango_files = 'E:/Music/Incompressible Files/Edits/Tango/NDCA Edits (128BPM)/'
            tangos = [f for f in os.listdir(tango_files) if f.endswith("flac")]
            tango_song = random.choice(tangos)
            tango, sr = librosa.load(os.path.join(tango_files, tango_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_tango = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_tango = int(fade_start_point_tango + (fade_duration * sr))
            tango_faded = tango[0:fade_end_point_tango].copy()
            for i in range(fade_start_point_tango,fade_end_point_tango):
                tango_faded[i] = tango[i] * fade_env[i-fade_start_point_tango]
                
            foxtrot_files = 'E:/Music/Incompressible Files/Edits/Std. Foxtrot/NDCA Edits (112BPM)/'
            foxtrots = [f for f in os.listdir(foxtrot_files) if f.endswith("flac")]
            foxtrot_song = random.choice(foxtrots)
            foxtrot, sr = librosa.load(os.path.join(foxtrot_files, foxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_foxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_foxtrot = int(fade_start_point_foxtrot + (fade_duration * sr))
            foxtrot_faded = foxtrot[0:fade_end_point_foxtrot].copy()
            for i in range(fade_start_point_foxtrot,fade_end_point_foxtrot):
                foxtrot_faded[i] = foxtrot[i] * fade_env[i-fade_start_point_foxtrot]
            
            quickstep_files = 'E:/Music/Incompressible Files/Edits/Quickstep/NDCA Edits (200BPM)/'
            quicksteps = [f for f in os.listdir(quickstep_files) if f.endswith("flac")]
            quickstep_song = random.choice(quicksteps)
            quickstep, sr = librosa.load(os.path.join(quickstep_files, quickstep_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_quickstep = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_quickstep = int(fade_start_point_quickstep + (fade_duration * sr))
            quickstep_faded = quickstep[0:fade_end_point_quickstep].copy()
            for i in range(fade_start_point_quickstep,fade_end_point_quickstep):
                quickstep_faded[i] = quickstep[i] * fade_env[i-fade_start_point_quickstep]
            
            sd.stop()
            fourdance_standard = np.concatenate([waltz_faded, silence, tango_faded, silence, foxtrot_faded, silence, quickstep_faded])
            sd.play(fourdance_standard, samplerate=sr)
        elif selected_level == "Championship":
            waltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/NDCA Edits (87BPM)/'
            waltzes = [f for f in os.listdir(waltz_files) if f.endswith("flac")]
            waltz_song = random.choice(waltzes)
            waltz, sr = librosa.load(os.path.join(waltz_files, waltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_waltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_waltz = int(fade_start_point_waltz + (fade_duration * sr))
            waltz_faded = waltz[0:fade_end_point_waltz].copy()
            for i in range(fade_start_point_waltz,fade_end_point_waltz):
                waltz_faded[i] = waltz[i] * fade_env[i-fade_start_point_waltz]
                
            tango_files = 'E:/Music/Incompressible Files/Edits/Tango/NDCA Edits (128BPM)/'
            tangos = [f for f in os.listdir(tango_files) if f.endswith("flac")]
            tango_song = random.choice(tangos)
            tango, sr = librosa.load(os.path.join(tango_files, tango_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_tango = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_tango = int(fade_start_point_tango + (fade_duration * sr))
            tango_faded = tango[0:fade_end_point_tango].copy()
            for i in range(fade_start_point_tango,fade_end_point_tango):
                tango_faded[i] = tango[i] * fade_env[i-fade_start_point_tango]
                
            vwaltz_files = 'E:/Music/Incompressible Files/Edits/Viennese Waltz/NDCA Edits (174BPM)/'
            vwaltzes = [f for f in os.listdir(vwaltz_files) if f.endswith("flac")]
            vwaltz_song = random.choice(vwaltzes)
            vwaltz, sr = librosa.load(os.path.join(vwaltz_files, vwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_vwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_vwaltz = int(fade_start_point_vwaltz + (fade_duration * sr))
            vwaltz_faded = vwaltz[0:fade_end_point_vwaltz].copy()
            for i in range(fade_start_point_vwaltz,fade_end_point_vwaltz):
                vwaltz_faded[i] = vwaltz[i] * fade_env[i-fade_start_point_vwaltz]
            
            foxtrot_files = 'E:/Music/Incompressible Files/Edits/Std. Foxtrot/NDCA Edits (112BPM)/'
            foxtrots = [f for f in os.listdir(foxtrot_files) if f.endswith("flac")]
            foxtrot_song = random.choice(foxtrots)
            foxtrot, sr = librosa.load(os.path.join(foxtrot_files, foxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_foxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_foxtrot = int(fade_start_point_foxtrot + (fade_duration * sr))
            foxtrot_faded = foxtrot[0:fade_end_point_foxtrot].copy()
            for i in range(fade_start_point_foxtrot,fade_end_point_foxtrot):
                foxtrot_faded[i] = foxtrot[i] * fade_env[i-fade_start_point_foxtrot]
            
            quickstep_files = 'E:/Music/Incompressible Files/Edits/Quickstep/NDCA Edits (200BPM)/'
            quicksteps = [f for f in os.listdir(quickstep_files) if f.endswith("flac")]
            quickstep_song = random.choice(quicksteps)
            quickstep, sr = librosa.load(os.path.join(quickstep_files, quickstep_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_quickstep = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_quickstep = int(fade_start_point_quickstep + (fade_duration * sr))
            quickstep_faded = quickstep[0:fade_end_point_quickstep].copy()
            for i in range(fade_start_point_quickstep,fade_end_point_quickstep):
                quickstep_faded[i] = quickstep[i] * fade_env[i-fade_start_point_quickstep]
            
            sd.stop()
            championship_standard = np.concatenate([waltz_faded, silence, tango_faded, silence, vwaltz_faded, silence, foxtrot_faded, silence, quickstep_faded])
            sd.play(championship_standard, samplerate=sr)
        elif selected_level == "Waltz":
            waltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/NDCA Edits (87BPM)/'
            waltzes = [f for f in os.listdir(waltz_files) if f.endswith("flac")]
            waltz_song = random.choice(waltzes)
            waltz, sr = librosa.load(os.path.join(waltz_files, waltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_waltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_waltz = int(fade_start_point_waltz + (fade_duration * sr))
            waltz_faded = waltz[0:fade_end_point_waltz].copy()
            for i in range(fade_start_point_waltz,fade_end_point_waltz):
                waltz_faded[i] = waltz[i] * fade_env[i-fade_start_point_waltz]
            
            sd.stop()
            sd.play(waltz_faded)
        elif selected_level == "Tango":
            tango_files = 'E:/Music/Incompressible Files/Edits/Tango/NDCA Edits (128BPM)/'
            tangos = [f for f in os.listdir(tango_files) if f.endswith("flac")]
            tango_song = random.choice(tangos)
            tango, sr = librosa.load(os.path.join(tango_files, tango_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_tango = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_tango = int(fade_start_point_tango + (fade_duration * sr))
            tango_faded = tango[0:fade_end_point_tango].copy()
            for i in range(fade_start_point_tango,fade_end_point_tango):
                tango_faded[i] = tango[i] * fade_env[i-fade_start_point_tango]
            sd.stop()
            sd.play(tango_faded)
            
        elif selected_level == "Viennese Waltz":
            vwaltz_files = 'E:/Music/Incompressible Files/Edits/Viennese Waltz/NDCA Edits (174BPM)/'
            vwaltzes = [f for f in os.listdir(vwaltz_files) if f.endswith("flac")]
            vwaltz_song = random.choice(vwaltzes)
            vwaltz, sr = librosa.load(os.path.join(vwaltz_files, vwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_vwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_vwaltz = int(fade_start_point_vwaltz + (fade_duration * sr))
            vwaltz_faded = vwaltz[0:fade_end_point_vwaltz].copy()
            for i in range(fade_start_point_vwaltz,fade_end_point_vwaltz):
                vwaltz_faded[i] = vwaltz[i] * fade_env[i-fade_start_point_vwaltz]
            
            sd.stop()
            sd.play(vwaltz_faded)
            
        elif selected_level == "Foxtrot":
            foxtrot_files = 'E:/Music/Incompressible Files/Edits/Std. Foxtrot/NDCA Edits (112BPM)/'
            foxtrots = [f for f in os.listdir(foxtrot_files) if f.endswith("flac")]
            foxtrot_song = random.choice(foxtrots)
            foxtrot, sr = librosa.load(os.path.join(foxtrot_files, foxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_foxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_foxtrot = int(fade_start_point_foxtrot + (fade_duration * sr))
            foxtrot_faded = foxtrot[0:fade_end_point_foxtrot].copy()
            for i in range(fade_start_point_foxtrot,fade_end_point_foxtrot):
                foxtrot_faded[i] = foxtrot[i] * fade_env[i-fade_start_point_foxtrot]
            
            sd.stop()
            sd.play(foxtrot_faded)
            
        elif selected_level == "Quickstep":
            quickstep_files = 'E:/Music/Incompressible Files/Edits/Quickstep/NDCA Edits (200BPM)/'
            quicksteps = [f for f in os.listdir(quickstep_files) if f.endswith("flac")]
            quickstep_song = random.choice(quicksteps)
            quickstep, sr = librosa.load(os.path.join(quickstep_files, quickstep_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_quickstep = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_quickstep = int(fade_start_point_quickstep + (fade_duration * sr))
            quickstep_faded = quickstep[0:fade_end_point_quickstep].copy()
            for i in range(fade_start_point_quickstep,fade_end_point_quickstep):
                quickstep_faded[i] = quickstep[i] * fade_env[i-fade_start_point_quickstep]
                        
            sd.stop()
            sd.play(quickstep_faded)
            
    elif selected_style == "Latin":
        if selected_level == "Novice":
            samba_files = 'E:/Music/Incompressible Files/Edits/Samba/NDCA Edits (100BPM)/'
            sambas = [f for f in os.listdir(samba_files) if f.endswith("flac")]
            samba_song = random.choice(sambas)
            samba, sr = librosa.load(os.path.join(samba_files, samba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_samba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_samba = int(fade_start_point_samba + (fade_duration * sr))
            samba_faded = samba[0:fade_end_point_samba].copy()
            for i in range(fade_start_point_samba,fade_end_point_samba):
                samba_faded[i] = samba[i] * fade_env[i-fade_start_point_samba]
            
            rumba_files = 'E:/Music/Incompressible Files/Edits/Intl Rumba/NDCA Edits (96BPM)/'
            rumbas = [f for f in os.listdir(rumba_files) if f.endswith("flac")]
            rumba_song = random.choice(rumbas)
            rumba, sr = librosa.load(os.path.join(rumba_files, rumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_rumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_rumba = int(fade_start_point_rumba + (fade_duration * sr))
            rumba_faded = rumba[0:fade_end_point_rumba].copy()
            for i in range(fade_start_point_rumba,fade_end_point_rumba):
                rumba_faded[i] = rumba[i] * fade_env[i-fade_start_point_rumba]
            
            sd.stop()
            novice_latin = np.concatenate([samba_faded, silence, rumba_faded])
            sd.play(novice_latin, samplerate=sr)
        elif selected_level == "Pre-Champ":
            ccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/NDCA Edits (124BPM)/'
            cccs = [f for f in os.listdir(ccc_files) if f.endswith("flac")]
            ccc_song = random.choice(cccs)
            ccc, sr = librosa.load(os.path.join(ccc_files, ccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_ccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_ccc = int(fade_start_point_ccc + (fade_duration * sr))
            ccc_faded = ccc[0:fade_end_point_ccc].copy()
            for i in range(fade_start_point_ccc,fade_end_point_ccc):
                ccc_faded[i] = ccc[i] * fade_env[i-fade_start_point_ccc]
                
            samba_files = 'E:/Music/Incompressible Files/Edits/Samba/NDCA Edits (100BPM)/'
            sambas = [f for f in os.listdir(samba_files) if f.endswith("flac")]
            samba_song = random.choice(sambas)
            samba, sr = librosa.load(os.path.join(samba_files, samba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_samba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_samba = int(fade_start_point_samba + (fade_duration * sr))
            samba_faded = samba[0:fade_end_point_samba].copy()
            for i in range(fade_start_point_samba,fade_end_point_samba):
                samba_faded[i] = samba[i] * fade_env[i-fade_start_point_samba]
            
            rumba_files = 'E:/Music/Incompressible Files/Edits/Intl Rumba/NDCA Edits (96BPM)/'
            rumbas = [f for f in os.listdir(rumba_files) if f.endswith("flac")]
            rumba_song = random.choice(rumbas)
            rumba, sr = librosa.load(os.path.join(rumba_files, rumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_rumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_rumba = int(fade_start_point_rumba + (fade_duration * sr))
            rumba_faded = rumba[0:fade_end_point_rumba].copy()
            for i in range(fade_start_point_rumba,fade_end_point_rumba):
                rumba_faded[i] = rumba[i] * fade_env[i-fade_start_point_rumba]
            
            sd.stop()
            prechamp_latin = np.concatenate([ccc_faded, silence, samba_faded, silence, rumba_faded])
            sd.play(prechamp_latin, samplerate=sr)
        elif selected_level == "4-Dance (2-Phrase Paso)":
            ccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/NDCA Edits (124BPM)/'
            cccs = [f for f in os.listdir(ccc_files) if f.endswith("flac")]
            ccc_song = random.choice(cccs)
            ccc, sr = librosa.load(os.path.join(ccc_files, ccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_ccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_ccc = int(fade_start_point_ccc + (fade_duration * sr))
            ccc_faded = ccc[0:fade_end_point_ccc].copy()
            for i in range(fade_start_point_ccc,fade_end_point_ccc):
                ccc_faded[i] = ccc[i] * fade_env[i-fade_start_point_ccc]
                
            samba_files = 'E:/Music/Incompressible Files/Edits/Samba/NDCA Edits (100BPM)/'
            sambas = [f for f in os.listdir(samba_files) if f.endswith("flac")]
            samba_song = random.choice(sambas)
            samba, sr = librosa.load(os.path.join(samba_files, samba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_samba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_samba = int(fade_start_point_samba + (fade_duration * sr))
            samba_faded = samba[0:fade_end_point_samba].copy()
            for i in range(fade_start_point_samba,fade_end_point_samba):
                samba_faded[i] = samba[i] * fade_env[i-fade_start_point_samba]
            
            rumba_files = 'E:/Music/Incompressible Files/Edits/Intl Rumba/NDCA Edits (96BPM)/'
            rumbas = [f for f in os.listdir(rumba_files) if f.endswith("flac")]
            rumba_song = random.choice(rumbas)
            rumba, sr = librosa.load(os.path.join(rumba_files, rumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_rumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_rumba = int(fade_start_point_rumba + (fade_duration * sr))
            rumba_faded = rumba[0:fade_end_point_rumba].copy()
            for i in range(fade_start_point_rumba,fade_end_point_rumba):
                rumba_faded[i] = rumba[i] * fade_env[i-fade_start_point_rumba]
                
            paso_files = 'E:/Music/Incompressible Files/Edits/Paso Doble/2-Phrased/NDCA Edits (110BPM)/'
            pasos = [f for f in os.listdir(paso_files) if f.endswith("flac")]
            paso_song = random.choice(pasos)
            paso2, sr = librosa.load(os.path.join(paso_files, paso_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            
            sd.stop()
            fourdance2_latin = np.concatenate([ccc_faded, silence, samba_faded, silence, rumba_faded, silence, paso2])
            sd.play(fourdance2_latin, samplerate=sr)
        elif selected_level == "4-Dance (3-Phrase Paso)":
            ccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/NDCA Edits (124BPM)/'
            cccs = [f for f in os.listdir(ccc_files) if f.endswith("flac")]
            ccc_song = random.choice(cccs)
            ccc, sr = librosa.load(os.path.join(ccc_files, ccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_ccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_ccc = int(fade_start_point_ccc + (fade_duration * sr))
            ccc_faded = ccc[0:fade_end_point_ccc].copy()
            for i in range(fade_start_point_ccc,fade_end_point_ccc):
                ccc_faded[i] = ccc[i] * fade_env[i-fade_start_point_ccc]
                
            samba_files = 'E:/Music/Incompressible Files/Edits/Samba/NDCA Edits (100BPM)/'
            sambas = [f for f in os.listdir(samba_files) if f.endswith("flac")]
            samba_song = random.choice(sambas)
            samba, sr = librosa.load(os.path.join(samba_files, samba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_samba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_samba = int(fade_start_point_samba + (fade_duration * sr))
            samba_faded = samba[0:fade_end_point_samba].copy()
            for i in range(fade_start_point_samba,fade_end_point_samba):
                samba_faded[i] = samba[i] * fade_env[i-fade_start_point_samba]
            
            rumba_files = 'E:/Music/Incompressible Files/Edits/Intl Rumba/NDCA Edits (96BPM)/'
            rumbas = [f for f in os.listdir(rumba_files) if f.endswith("flac")]
            rumba_song = random.choice(rumbas)
            rumba, sr = librosa.load(os.path.join(rumba_files, rumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_rumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_rumba = int(fade_start_point_rumba + (fade_duration * sr))
            rumba_faded = rumba[0:fade_end_point_rumba].copy()
            for i in range(fade_start_point_rumba,fade_end_point_rumba):
                rumba_faded[i] = rumba[i] * fade_env[i-fade_start_point_rumba]
                
            paso_files = 'E:/Music/Incompressible Files/Edits/Paso Doble/3-Phrased/NDCA Edits (110BPM)/'
            pasos = [f for f in os.listdir(paso_files) if f.endswith("flac")]
            paso_song = random.choice(pasos)
            paso3, sr = librosa.load(os.path.join(paso_files, paso_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            
            sd.stop()
            fourdance3_latin = np.concatenate([ccc_faded, silence, samba_faded, silence, rumba_faded, silence, paso3])
            sd.play(fourdance3_latin, samplerate=sr)
        elif selected_level == "Championship (2-Phrase Paso)":
            ccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/NDCA Edits (124BPM)/'
            cccs = [f for f in os.listdir(ccc_files) if f.endswith("flac")]
            ccc_song = random.choice(cccs)
            ccc, sr = librosa.load(os.path.join(ccc_files, ccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_ccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_ccc = int(fade_start_point_ccc + (fade_duration * sr))
            ccc_faded = ccc[0:fade_end_point_ccc].copy()
            for i in range(fade_start_point_ccc,fade_end_point_ccc):
                ccc_faded[i] = ccc[i] * fade_env[i-fade_start_point_ccc]
                
            samba_files = 'E:/Music/Incompressible Files/Edits/Samba/NDCA Edits (100BPM)/'
            sambas = [f for f in os.listdir(samba_files) if f.endswith("flac")]
            samba_song = random.choice(sambas)
            samba, sr = librosa.load(os.path.join(samba_files, samba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_samba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_samba = int(fade_start_point_samba + (fade_duration * sr))
            samba_faded = samba[0:fade_end_point_samba].copy()
            for i in range(fade_start_point_samba,fade_end_point_samba):
                samba_faded[i] = samba[i] * fade_env[i-fade_start_point_samba]
            
            rumba_files = 'E:/Music/Incompressible Files/Edits/Intl Rumba/NDCA Edits (96BPM)/'
            rumbas = [f for f in os.listdir(rumba_files) if f.endswith("flac")]
            rumba_song = random.choice(rumbas)
            rumba, sr = librosa.load(os.path.join(rumba_files, rumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_rumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_rumba = int(fade_start_point_rumba + (fade_duration * sr))
            rumba_faded = rumba[0:fade_end_point_rumba].copy()
            for i in range(fade_start_point_rumba,fade_end_point_rumba):
                rumba_faded[i] = rumba[i] * fade_env[i-fade_start_point_rumba]
                
            paso_files = 'E:/Music/Incompressible Files/Edits/Paso Doble/2-Phrased/NDCA Edits (110BPM)/'
            pasos = [f for f in os.listdir(paso_files) if f.endswith("flac")]
            paso_song = random.choice(pasos)
            paso2, sr = librosa.load(os.path.join(paso_files, paso_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            
            jive_files = 'E:/Music/Incompressible Files/Edits/Jive/NDCA Edits (172BPM)/'
            jives = [f for f in os.listdir(jive_files) if f.endswith("flac")]
            jive_song = random.choice(jives)
            jive, sr = librosa.load(os.path.join(jive_files, jive_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_jive = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_jive = int(fade_start_point_jive + (fade_duration * sr))
            jive_faded = jive[0:fade_end_point_jive].copy()
            for i in range(fade_start_point_jive,fade_end_point_jive):
                jive_faded[i] = jive[i] * fade_env[i-fade_start_point_jive]
            
            sd.stop()
            championship2_latin = np.concatenate([ccc_faded, silence, samba_faded, silence, rumba_faded, silence, paso2, silence, jive_faded])
            sd.play(championship2_latin, samplerate=sr)
        elif selected_level == "Championship (3-Phrase Paso)":
            ccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/NDCA Edits (124BPM)/'
            cccs = [f for f in os.listdir(ccc_files) if f.endswith("flac")]
            ccc_song = random.choice(cccs)
            ccc, sr = librosa.load(os.path.join(ccc_files, ccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_ccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_ccc = int(fade_start_point_ccc + (fade_duration * sr))
            ccc_faded = ccc[0:fade_end_point_ccc].copy()
            for i in range(fade_start_point_ccc,fade_end_point_ccc):
                ccc_faded[i] = ccc[i] * fade_env[i-fade_start_point_ccc]
                
            samba_files = 'E:/Music/Incompressible Files/Edits/Samba/NDCA Edits (100BPM)/'
            sambas = [f for f in os.listdir(samba_files) if f.endswith("flac")]
            samba_song = random.choice(sambas)
            samba, sr = librosa.load(os.path.join(samba_files, samba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_samba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_samba = int(fade_start_point_samba + (fade_duration * sr))
            samba_faded = samba[0:fade_end_point_samba].copy()
            for i in range(fade_start_point_samba,fade_end_point_samba):
                samba_faded[i] = samba[i] * fade_env[i-fade_start_point_samba]
            
            rumba_files = 'E:/Music/Incompressible Files/Edits/Intl Rumba/NDCA Edits (96BPM)/'
            rumbas = [f for f in os.listdir(rumba_files) if f.endswith("flac")]
            rumba_song = random.choice(rumbas)
            rumba, sr = librosa.load(os.path.join(rumba_files, rumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_rumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_rumba = int(fade_start_point_rumba + (fade_duration * sr))
            rumba_faded = rumba[0:fade_end_point_rumba].copy()
            for i in range(fade_start_point_rumba,fade_end_point_rumba):
                rumba_faded[i] = rumba[i] * fade_env[i-fade_start_point_rumba]
                
            paso_files = 'E:/Music/Incompressible Files/Edits/Paso Doble/3-Phrased/NDCA Edits (110BPM)/'
            pasos = [f for f in os.listdir(paso_files) if f.endswith("flac")]
            paso_song = random.choice(pasos)
            paso3, sr = librosa.load(os.path.join(paso_files, paso_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            
            jive_files = 'E:/Music/Incompressible Files/Edits/Jive/NDCA Edits (172BPM)/'
            jives = [f for f in os.listdir(jive_files) if f.endswith("flac")]
            jive_song = random.choice(jives)
            jive, sr = librosa.load(os.path.join(jive_files, jive_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_jive = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_jive = int(fade_start_point_jive + (fade_duration * sr))
            jive_faded = jive[0:fade_end_point_jive].copy()
            for i in range(fade_start_point_jive,fade_end_point_jive):
                jive_faded[i] = jive[i] * fade_env[i-fade_start_point_jive]
            
            sd.stop()
            championship3_latin = np.concatenate([ccc_faded, silence, samba_faded, silence, rumba_faded, silence, paso3, silence, jive_faded])
            sd.play(championship3_latin, samplerate=sr)
            
        if selected_level == "Cha Cha":
            ccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/NDCA Edits (124BPM)/'
            cccs = [f for f in os.listdir(ccc_files) if f.endswith("flac")]
            ccc_song = random.choice(cccs)
            ccc, sr = librosa.load(os.path.join(ccc_files, ccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_ccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_ccc = int(fade_start_point_ccc + (fade_duration * sr))
            ccc_faded = ccc[0:fade_end_point_ccc].copy()
            for i in range(fade_start_point_ccc,fade_end_point_ccc):
                ccc_faded[i] = ccc[i] * fade_env[i-fade_start_point_ccc]
            
            sd.stop()
            sd.play(ccc_faded)

        elif selected_level == "Samba":
            samba_files = 'E:/Music/Incompressible Files/Edits/Samba/NDCA Edits (100BPM)/'
            sambas = [f for f in os.listdir(samba_files) if f.endswith("flac")]
            samba_song = random.choice(sambas)
            samba, sr = librosa.load(os.path.join(samba_files, samba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_samba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_samba = int(fade_start_point_samba + (fade_duration * sr))
            samba_faded = samba[0:fade_end_point_samba].copy()
            for i in range(fade_start_point_samba,fade_end_point_samba):
                samba_faded[i] = samba[i] * fade_env[i-fade_start_point_samba]
            
            sd.stop()
            sd.play(samba_faded)
            
        elif selected_level == "Rumba":
            rumba_files = 'E:/Music/Incompressible Files/Edits/Intl Rumba/NDCA Edits (96BPM)/'
            rumbas = [f for f in os.listdir(rumba_files) if f.endswith("flac")]
            rumba_song = random.choice(rumbas)
            rumba, sr = librosa.load(os.path.join(rumba_files, rumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_rumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_rumba = int(fade_start_point_rumba + (fade_duration * sr))
            rumba_faded = rumba[0:fade_end_point_rumba].copy()
            for i in range(fade_start_point_rumba,fade_end_point_rumba):
                rumba_faded[i] = rumba[i] * fade_env[i-fade_start_point_rumba]
            
            sd.stop()
            sd.play(rumba_faded)
            
        elif selected_level == "2-Phrased Paso Doble":
            paso_files = 'E:/Music/Incompressible Files/Edits/Paso Doble/2-Phrased/NDCA Edits (110BPM)/'
            pasos = [f for f in os.listdir(paso_files) if f.endswith("flac")]
            paso_song = random.choice(pasos)
            paso2, sr = librosa.load(os.path.join(paso_files, paso_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            
            sd.stop()
            sd.play(paso2)
            
        elif selected_level == "3-Phrased Paso Doble":
            paso_files = 'E:/Music/Incompressible Files/Edits/Paso Doble/3-Phrased/NDCA Edits (110BPM)/'
            pasos = [f for f in os.listdir(paso_files) if f.endswith("flac")]
            paso_song = random.choice(pasos)
            paso3, sr = librosa.load(os.path.join(paso_files, paso_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            
            sd.stop()
            sd.play(paso3)
            
        elif selected_level == "Jive":
            jive_files = 'E:/Music/Incompressible Files/Edits/Jive/NDCA Edits (172BPM)/'
            jives = [f for f in os.listdir(jive_files) if f.endswith("flac")]
            jive_song = random.choice(jives)
            jive, sr = librosa.load(os.path.join(jive_files, jive_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_jive = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_jive = int(fade_start_point_jive + (fade_duration * sr))
            jive_faded = jive[0:fade_end_point_jive].copy()
            for i in range(fade_start_point_jive,fade_end_point_jive):
                jive_faded[i] = jive[i] * fade_env[i-fade_start_point_jive]
            
            sd.stop()
            sd.play(jive_faded)
            
    elif selected_style == "Smooth":
        if selected_level == "Novice":
            amwaltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/WDSF & Smooth Edits (90BPM)/'
            amwaltzes = [f for f in os.listdir(amwaltz_files) if f.endswith("flac")]
            amwaltz_song = random.choice(amwaltzes)
            amwaltz, sr = librosa.load(os.path.join(amwaltz_files, amwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amwaltz = int(fade_start_point_amwaltz + (fade_duration * sr))
            amwaltz_faded = amwaltz[0:fade_end_point_amwaltz].copy()
            for i in range(fade_start_point_amwaltz,fade_end_point_amwaltz):
                amwaltz_faded[i] = amwaltz[i] * fade_env[i-fade_start_point_amwaltz]
                
            amfoxtrot_files = 'E:/Music/Incompressible Files/Edits/Smooth Foxtrot/WDSF & Smooth Edits (120BPM)/'
            amfoxtrots = [f for f in os.listdir(amfoxtrot_files) if f.endswith("flac")]
            amfoxtrot_song = random.choice(amfoxtrots)
            amfoxtrot, sr = librosa.load(os.path.join(amfoxtrot_files, amfoxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amfoxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amfoxtrot = int(fade_start_point_amfoxtrot + (fade_duration * sr))
            amfoxtrot_faded = amfoxtrot[0:fade_end_point_amfoxtrot].copy()
            for i in range(fade_start_point_amfoxtrot,fade_end_point_amfoxtrot):
                amfoxtrot_faded[i] = amfoxtrot[i] * fade_env[i-fade_start_point_amfoxtrot]
                
            sd.stop()
            novice_smooth = np.concatenate([amwaltz_faded, silence, amfoxtrot_faded])
            sd.play(novice_smooth, samplerate=sr)
        elif selected_level == "Pre-Champ":
            amwaltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/WDSF & Smooth Edits (90BPM)/'
            amwaltzes = [f for f in os.listdir(amwaltz_files) if f.endswith("flac")]
            amwaltz_song = random.choice(amwaltzes)
            amwaltz, sr = librosa.load(os.path.join(amwaltz_files, amwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amwaltz = int(fade_start_point_amwaltz + (fade_duration * sr))
            amwaltz_faded = amwaltz[0:fade_end_point_amwaltz].copy()
            for i in range(fade_start_point_amwaltz,fade_end_point_amwaltz):
                amwaltz_faded[i] = amwaltz[i] * fade_env[i-fade_start_point_amwaltz]
            
            amtango_files = 'E:/Music/Incompressible Files/Edits/Tango/Smooth Edits (120BPM)/'
            amtangos = [f for f in os.listdir(amtango_files) if f.endswith("flac")]
            amtango_song = random.choice(amtangos)
            amtango, sr = librosa.load(os.path.join(amtango_files, amtango_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amtango = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amtango = int(fade_start_point_amtango + (fade_duration * sr))
            amtango_faded = amtango[0:fade_end_point_amtango].copy()
            for i in range(fade_start_point_amtango,fade_end_point_amtango):
                amtango_faded[i] = amtango[i] * fade_env[i-fade_start_point_amtango]
                
            amfoxtrot_files = 'E:/Music/Incompressible Files/Edits/Smooth Foxtrot/WDSF & Smooth Edits (120BPM)/'
            amfoxtrots = [f for f in os.listdir(amfoxtrot_files) if f.endswith("flac")]
            amfoxtrot_song = random.choice(amfoxtrots)
            amfoxtrot, sr = librosa.load(os.path.join(amfoxtrot_files, amfoxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amfoxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amfoxtrot = int(fade_start_point_amfoxtrot + (fade_duration * sr))
            amfoxtrot_faded = amfoxtrot[0:fade_end_point_amfoxtrot].copy()
            for i in range(fade_start_point_amfoxtrot,fade_end_point_amfoxtrot):
                amfoxtrot_faded[i] = amfoxtrot[i] * fade_env[i-fade_start_point_amfoxtrot]
            
            sd.stop()
            prechamp_smooth = np.concatenate([amwaltz_faded, silence, amtango_faded, silence, amfoxtrot_faded])
            sd.play(prechamp_smooth, samplerate=sr)
        elif selected_level == "Championship":
            amwaltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/WDSF & Smooth Edits (90BPM)/'
            amwaltzes = [f for f in os.listdir(amwaltz_files) if f.endswith("flac")]
            amwaltz_song = random.choice(amwaltzes)
            amwaltz, sr = librosa.load(os.path.join(amwaltz_files, amwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amwaltz = int(fade_start_point_amwaltz + (fade_duration * sr))
            amwaltz_faded = amwaltz[0:fade_end_point_amwaltz].copy()
            for i in range(fade_start_point_amwaltz,fade_end_point_amwaltz):
                amwaltz_faded[i] = amwaltz[i] * fade_env[i-fade_start_point_amwaltz]
            
            amtango_files = 'E:/Music/Incompressible Files/Edits/Tango/Smooth Edits (120BPM)/'
            amtangos = [f for f in os.listdir(amtango_files) if f.endswith("flac")]
            amtango_song = random.choice(amtangos)
            amtango, sr = librosa.load(os.path.join(amtango_files, amtango_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amtango = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amtango = int(fade_start_point_amtango + (fade_duration * sr))
            amtango_faded = amtango[0:fade_end_point_amtango].copy()
            for i in range(fade_start_point_amtango,fade_end_point_amtango):
                amtango_faded[i] = amtango[i] * fade_env[i-fade_start_point_amtango]
                
            amfoxtrot_files = 'E:/Music/Incompressible Files/Edits/Smooth Foxtrot/WDSF & Smooth Edits (120BPM)/'
            amfoxtrots = [f for f in os.listdir(amfoxtrot_files) if f.endswith("flac")]
            amfoxtrot_song = random.choice(amfoxtrots)
            amfoxtrot, sr = librosa.load(os.path.join(amfoxtrot_files, amfoxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amfoxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amfoxtrot = int(fade_start_point_amfoxtrot + (fade_duration * sr))
            amfoxtrot_faded = amfoxtrot[0:fade_end_point_amfoxtrot].copy()
            for i in range(fade_start_point_amfoxtrot,fade_end_point_amfoxtrot):
                amfoxtrot_faded[i] = amfoxtrot[i] * fade_env[i-fade_start_point_amfoxtrot]
            
            amvwaltz_files = 'E:/Music/Incompressible Files/Edits/Viennese Waltz/Smooth Edits (159BPM)/'
            amvwaltzes = [f for f in os.listdir(amvwaltz_files) if f.endswith("flac")]
            amvwaltz_song = random.choice(amvwaltzes)
            amvwaltz, sr = librosa.load(os.path.join(amvwaltz_files, amvwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amvwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amvwaltz = int(fade_start_point_amvwaltz + (fade_duration * sr))
            amvwaltz_faded = amvwaltz[0:fade_end_point_amvwaltz].copy()
            for i in range(fade_start_point_amvwaltz,fade_end_point_amvwaltz):
                amvwaltz_faded[i] = amvwaltz[i] * fade_env[i-fade_start_point_amvwaltz]
            
            sd.stop()
            championship_smooth = np.concatenate([amwaltz_faded, silence, amtango_faded, silence, amfoxtrot_faded, silence, amvwaltz_faded])
            sd.play(championship_smooth, samplerate=sr)
            
        elif selected_level == "Waltz":
            amwaltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/WDSF & Smooth Edits (90BPM)/'
            amwaltzes = [f for f in os.listdir(amwaltz_files) if f.endswith("flac")]
            amwaltz_song = random.choice(amwaltzes)
            amwaltz, sr = librosa.load(os.path.join(amwaltz_files, amwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amwaltz = int(fade_start_point_amwaltz + (fade_duration * sr))
            amwaltz_faded = amwaltz[0:fade_end_point_amwaltz].copy()
            for i in range(fade_start_point_amwaltz,fade_end_point_amwaltz):
                amwaltz_faded[i] = amwaltz[i] * fade_env[i-fade_start_point_amwaltz]
            
            sd.stop()
            sd.play(amwaltz_faded)
        elif selected_level == "Tango":
            amtango_files = 'E:/Music/Incompressible Files/Edits/Tango/Smooth Edits (120BPM)/'
            amtangos = [f for f in os.listdir(amtango_files) if f.endswith("flac")]
            amtango_song = random.choice(amtangos)
            amtango, sr = librosa.load(os.path.join(amtango_files, amtango_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amtango = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amtango = int(fade_start_point_tango + (fade_duration * sr))
            amtango_faded = amtango[0:fade_end_point_amtango].copy()
            for i in range(fade_start_point_amtango,fade_end_point_amtango):
                amtango_faded[i] = amtango[i] * fade_env[i-fade_start_point_amtango]
                
            sd.stop()
            sd.play(amtango_faded)
        elif selected_level == "Foxtrot":
            amfoxtrot_files = 'E:/Music/Incompressible Files/Edits/Smooth Foxtrot/WDSF & Smooth Edits (120BPM)/'
            amfoxtrots = [f for f in os.listdir(amfoxtrot_files) if f.endswith("flac")]
            amfoxtrot_song = random.choice(amfoxtrots)
            amfoxtrot, sr = librosa.load(os.path.join(amfoxtrot_files, amfoxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amfoxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amfoxtrot = int(fade_start_point_amfoxtrot + (fade_duration * sr))
            amfoxtrot_faded = amfoxtrot[0:fade_end_point_amfoxtrot].copy()
            for i in range(fade_start_point_amfoxtrot,fade_end_point_amfoxtrot):
                amfoxtrot_faded[i] = amfoxtrot[i] * fade_env[i-fade_start_point_amfoxtrot]
            
            sd.stop()
            sd.play(amfoxtrot_faded)
        elif selected_level == "Viennese Waltz":
            amvwaltz_files = 'E:/Music/Incompressible Files/Edits/Viennese Waltz/Smooth Edits (159BPM)/'
            amvwaltzes = [f for f in os.listdir(amvwaltz_files) if f.endswith("flac")]
            amvwaltz_song = random.choice(amvwaltzes)
            amvwaltz, sr = librosa.load(os.path.join(amvwaltz_files, amvwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amvwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amvwaltz = int(fade_start_point_amvwaltz + (fade_duration * sr))
            amvwaltz_faded = amvwaltz[0:fade_end_point_amvwaltz].copy()
            for i in range(fade_start_point_amvwaltz,fade_end_point_amvwaltz):
                amvwaltz_faded[i] = amvwaltz[i] * fade_env[i-fade_start_point_amvwaltz]
            
            sd.stop()
            sd.play(amvwaltz_faded)
            
    elif selected_style == "Rhythm":
        if selected_level == "Novice (CC/M)":
            amccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/Rhythm Edits (120BPM)/'
            amcccs = [f for f in os.listdir(amccc_files) if f.endswith("flac")]
            amccc_song = random.choice(amcccs)
            amccc, sr = librosa.load(os.path.join(amccc_files, amccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amccc = int(fade_start_point_amccc + (fade_duration * sr))
            amccc_faded = amccc[0:fade_end_point_amccc].copy()
            for i in range(fade_start_point_amccc,fade_end_point_amccc):
                amccc_faded[i] = amccc[i] * fade_env[i-fade_start_point_amccc]
                
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
                
            sd.stop()
            novice1_rhythm = np.concatenate([amccc_faded, silence, mambo_faded])
            sd.play(novice1_rhythm, samplerate=sr)
        elif selected_level == "Novice (Sw/M)":
            swing_files = 'E:/Music/Incompressible Files/Edits/Swing/Rhythm Edits (140BPM)/'
            swings = [f for f in os.listdir(swing_files) if f.endswith("flac")]
            swing_song = random.choice(swing)
            swing, sr = librosa.load(os.path.join(swing_files, swing_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_swing = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_swing = int(fade_start_point_swing + (fade_duration * sr))
            swing_faded = swing[0:fade_end_point_swing].copy()
            for i in range(fade_start_point_swing,fade_end_point_swing):
                swing_faded[i] = swing[i] * fade_env[i-fade_start_point_swing]
                
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
                
            sd.stop()
            novice2_rhythm = np.concatenate([swing_faded, silence, mambo_faded])
            sd.play(novice2_rhythm, samplerate=sr)
        elif selected_level == "Novice (B/M)":
            bolero_files = 'E:/Music/Incompressible Files/Edits/Bolero/Rhythm Edits (92BPM)/'
            boleros = [f for f in os.listdir(bolero_files) if f.endswith("flac")]
            bolero_song = random.choice(boleros)
            bolero, sr = librosa.load(os.path.join(bolero_files, bolero_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_bolero = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_bolero = int(fade_start_point_bolero + (fade_duration * sr))
            bolero_faded = bolero[0:fade_end_point_bolero].copy()
            for i in range(fade_start_point_bolero,fade_end_point_bolero):
                bolero_faded[i] = bolero[i] * fade_env[i-fade_start_point_bolero]
                
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
            
            sd.stop()
            novice3_rhythm = np.concatenate([bolero_faded, silence, mambo_faded])
            sd.play(novice3_rhythm, samplerate=sr)
        elif selected_level == "Pre-Champ (CC/Sw/M)":
            amccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/Rhythm Edits (120BPM)/'
            amcccs = [f for f in os.listdir(amccc_files) if f.endswith("flac")]
            amccc_song = random.choice(amcccs)
            amccc, sr = librosa.load(os.path.join(amccc_files, amccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amccc = int(fade_start_point_amccc + (fade_duration * sr))
            amccc_faded = amccc[0:fade_end_point_amccc].copy()
            for i in range(fade_start_point_amccc,fade_end_point_amccc):
                amccc_faded[i] = amccc[i] * fade_env[i-fade_start_point_amccc]
                
            swing_files = 'E:/Music/Incompressible Files/Edits/Swing/Rhythm Edits (140BPM)/'
            swings = [f for f in os.listdir(swing_files) if f.endswith("flac")]
            swing_song = random.choice(swing)
            swing, sr = librosa.load(os.path.join(swing_files, swing_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_swing = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_swing = int(fade_start_point_swing + (fade_duration * sr))
            swing_faded = swing[0:fade_end_point_swing].copy()
            for i in range(fade_start_point_swing,fade_end_point_swing):
                swing_faded[i] = swing[i] * fade_env[i-fade_start_point_swing]
                
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
                
            sd.stop()
            prechamp1_rhythm = np.concatenate([amccc_faded, silence, swing_faded, silence, mambo_faded])
            sd.play(prechamp1_rhythm, samplerate=sr)
        elif selected_level == "Pre-Champ (CC/B/M)":
            amccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/Rhythm Edits (120BPM)/'
            amcccs = [f for f in os.listdir(amccc_files) if f.endswith("flac")]
            amccc_song = random.choice(amcccs)
            amccc, sr = librosa.load(os.path.join(amccc_files, amccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amccc = int(fade_start_point_amccc + (fade_duration * sr))
            amccc_faded = amccc[0:fade_end_point_amccc].copy()
            for i in range(fade_start_point_amccc,fade_end_point_amccc):
                amccc_faded[i] = amccc[i] * fade_env[i-fade_start_point_amccc]
                
            bolero_files = 'E:/Music/Incompressible Files/Edits/Bolero/Rhythm Edits (92BPM)/'
            boleros = [f for f in os.listdir(bolero_files) if f.endswith("flac")]
            bolero_song = random.choice(boleros)
            bolero, sr = librosa.load(os.path.join(bolero_files, bolero_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_bolero = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_bolero = int(fade_start_point_bolero + (fade_duration * sr))
            bolero_faded = bolero[0:fade_end_point_bolero].copy()
            for i in range(fade_start_point_bolero,fade_end_point_bolero):
                bolero_faded[i] = bolero[i] * fade_env[i-fade_start_point_bolero]
                
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
            
            sd.stop()
            prechamp2_rhythm = np.concatenate([amccc_faded, silence, bolero_faded, silence, mambo_faded])
            sd.play(prechamp2_rhythm, samplerate=sr)
        elif selected_level == "Pre-Champ (Sw/B/M)":
            swing_files = 'E:/Music/Incompressible Files/Edits/Swing/Rhythm Edits (140BPM)/'
            swings = [f for f in os.listdir(swing_files) if f.endswith("flac")]
            swing_song = random.choice(swing)
            swing, sr = librosa.load(os.path.join(swing_files, swing_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_swing = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_swing = int(fade_start_point_swing + (fade_duration * sr))
            swing_faded = swing[0:fade_end_point_swing].copy()
            for i in range(fade_start_point_swing,fade_end_point_swing):
                swing_faded[i] = swing[i] * fade_env[i-fade_start_point_swing]
                
            bolero_files = 'E:/Music/Incompressible Files/Edits/Bolero/Rhythm Edits (92BPM)/'
            boleros = [f for f in os.listdir(bolero_files) if f.endswith("flac")]
            bolero_song = random.choice(boleros)
            bolero, sr = librosa.load(os.path.join(bolero_files, bolero_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_bolero = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_bolero = int(fade_start_point_bolero + (fade_duration * sr))
            bolero_faded = bolero[0:fade_end_point_bolero].copy()
            for i in range(fade_start_point_bolero,fade_end_point_bolero):
                bolero_faded[i] = bolero[i] * fade_env[i-fade_start_point_bolero]
                
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
            
            sd.stop()
            prechamp3_rhythm = np.concatenate([swing_faded, silence, bolero_faded, silence, mambo_faded])
            sd.play(prechamp3_rhythm, samplerate=sr)
        elif selected_level == "4-Dance (CC/Sw/B/M)":
            amccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/Rhythm Edits (120BPM)/'
            amcccs = [f for f in os.listdir(amccc_files) if f.endswith("flac")]
            amccc_song = random.choice(amcccs)
            amccc, sr = librosa.load(os.path.join(amccc_files, amccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amccc = int(fade_start_point_amccc + (fade_duration * sr))
            amccc_faded = amccc[0:fade_end_point_amccc].copy()
            for i in range(fade_start_point_amccc,fade_end_point_amccc):
                amccc_faded[i] = amccc[i] * fade_env[i-fade_start_point_amccc]
                
            swing_files = 'E:/Music/Incompressible Files/Edits/Swing/Rhythm Edits (140BPM)/'
            swings = [f for f in os.listdir(swing_files) if f.endswith("flac")]
            swing_song = random.choice(swing)
            swing, sr = librosa.load(os.path.join(swing_files, swing_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_swing = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_swing = int(fade_start_point_swing + (fade_duration * sr))
            swing_faded = swing[0:fade_end_point_swing].copy()
            for i in range(fade_start_point_swing,fade_end_point_swing):
                swing_faded[i] = swing[i] * fade_env[i-fade_start_point_swing]
                
            bolero_files = 'E:/Music/Incompressible Files/Edits/Bolero/Rhythm Edits (92BPM)/'
            boleros = [f for f in os.listdir(bolero_files) if f.endswith("flac")]
            bolero_song = random.choice(boleros)
            bolero, sr = librosa.load(os.path.join(bolero_files, bolero_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_bolero = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_bolero = int(fade_start_point_bolero + (fade_duration * sr))
            bolero_faded = bolero[0:fade_end_point_bolero].copy()
            for i in range(fade_start_point_bolero,fade_end_point_bolero):
                bolero_faded[i] = bolero[i] * fade_env[i-fade_start_point_bolero]
                
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
                
            sd.stop()
            fourdance_rhythm = np.concatenate([amccc_faded, silence, swing_faded, silence, bolero_faded, silence, mambo_faded])
            sd.play(fourdance_rhythm)
        elif selected_level == "Championship":
            amccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/Rhythm Edits (120BPM)/'
            amcccs = [f for f in os.listdir(amccc_files) if f.endswith("flac")]
            amccc_song = random.choice(amcccs)
            amccc, sr = librosa.load(os.path.join(amccc_files, amccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amccc = int(fade_start_point_amccc + (fade_duration * sr))
            amccc_faded = amccc[0:fade_end_point_amccc].copy()
            for i in range(fade_start_point_amccc,fade_end_point_amccc):
                amccc_faded[i] = amccc[i] * fade_env[i-fade_start_point_amccc]
            
            amrumba_files = 'E:/Music/Incompressible Files/Edits/American Rumba/NDCA Edits (124BPM)/'
            amrumbas = [f for f in os.listdir(amrumba_files) if f.endswith("flac")]
            amrumba_song = random.choice(amrumbas)
            amrumba, sr = librosa.load(os.path.join(amrumba_files, amrumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amrumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amrumba = int(fade_start_point_amrumba + (fade_duration * sr))
            amrumba_faded = amrumba[0:fade_end_point_amrumba].copy()
            for i in range(fade_start_point_amrumba,fade_end_point_amrumba):
                amrumba_faded[i] = amrumba[i] * fade_env[i-fade_start_point_amrumba]
                
            swing_files = 'E:/Music/Incompressible Files/Edits/Swing/Rhythm Edits (140BPM)/'
            swings = [f for f in os.listdir(swing_files) if f.endswith("flac")]
            swing_song = random.choice(swing)
            swing, sr = librosa.load(os.path.join(swing_files, swing_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_swing = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_swing = int(fade_start_point_swing + (fade_duration * sr))
            swing_faded = swing[0:fade_end_point_swing].copy()
            for i in range(fade_start_point_swing,fade_end_point_swing):
                swing_faded[i] = swing[i] * fade_env[i-fade_start_point_swing]
                
            bolero_files = 'E:/Music/Incompressible Files/Edits/Bolero/Rhythm Edits (92BPM)/'
            boleros = [f for f in os.listdir(bolero_files) if f.endswith("flac")]
            bolero_song = random.choice(boleros)
            bolero, sr = librosa.load(os.path.join(bolero_files, bolero_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_bolero = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_bolero = int(fade_start_point_bolero + (fade_duration * sr))
            bolero_faded = bolero[0:fade_end_point_bolero].copy()
            for i in range(fade_start_point_bolero,fade_end_point_bolero):
                bolero_faded[i] = bolero[i] * fade_env[i-fade_start_point_bolero]
                
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
                
            sd.stop()
            championship_rhythm = np.concatenate([amccc_faded, silence, amrumba_faded, silence, swing_faded, silence, bolero_faded, silence, mambo_faded])
            sd.play(championship_rhythm)
            
        elif selected_level == "Cha Cha":
            amccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/Rhythm Edits (120BPM)/'
            amcccs = [f for f in os.listdir(amccc_files) if f.endswith("flac")]
            amccc_song = random.choice(amcccs)
            amccc, sr = librosa.load(os.path.join(amccc_files, amccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amccc = int(fade_start_point_amccc + (fade_duration * sr))
            amccc_faded = amccc[0:fade_end_point_amccc].copy()
            for i in range(fade_start_point_amccc,fade_end_point_amccc):
                amccc_faded[i] = amccc[i] * fade_env[i-fade_start_point_amccc]
            
            sd.stop()
            sd.play(amccc_faded)
        elif selected_level == "Rumba":
            amrumba_files = 'E:/Music/Incompressible Files/Edits/American Rumba/NDCA Edits (124BPM)/'
            amrumbas = [f for f in os.listdir(amrumba_files) if f.endswith("flac")]
            amrumba_song = random.choice(amrumbas)
            amrumba, sr = librosa.load(os.path.join(amrumba_files, amrumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amrumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amrumba = int(fade_start_point_amrumba + (fade_duration * sr))
            amrumba_faded = amrumba[0:fade_end_point_amrumba].copy()
            for i in range(fade_start_point_amrumba,fade_end_point_amrumba):
                amrumba_faded[i] = amrumba[i] * fade_env[i-fade_start_point_amrumba]
            
            sd.stop()
            sd.play(amrumba_faded)
        elif selected_level == "Swing":
            swing_files = 'E:/Music/Incompressible Files/Edits/Swing/Rhythm Edits (140BPM)/'
            swings = [f for f in os.listdir(swing_files) if f.endswith("flac")]
            swing_song = random.choice(swing)
            swing, sr = librosa.load(os.path.join(swing_files, swing_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_swing = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_swing = int(fade_start_point_swing + (fade_duration * sr))
            swing_faded = swing[0:fade_end_point_swing].copy()
            for i in range(fade_start_point_swing,fade_end_point_swing):
                swing_faded[i] = swing[i] * fade_env[i-fade_start_point_swing]
                
            sd.stop()
            sd.play(swing_faded)
        elif selected_level == "Bolero":
            bolero_files = 'E:/Music/Incompressible Files/Edits/Bolero/Rhythm Edits (92BPM)/'
            boleros = [f for f in os.listdir(bolero_files) if f.endswith("flac")]
            bolero_song = random.choice(boleros)
            bolero, sr = librosa.load(os.path.join(bolero_files, bolero_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_bolero = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_bolero = int(fade_start_point_bolero + (fade_duration * sr))
            bolero_faded = bolero[0:fade_end_point_bolero].copy()
            for i in range(fade_start_point_bolero,fade_end_point_bolero):
                bolero_faded[i] = bolero[i] * fade_env[i-fade_start_point_bolero]
                
            sd.stop()
            sd.play(bolero_faded)
        elif selected_level == "Mambo":
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
                
            sd.stop()
            sd.play(mambo_faded)
            
    elif selected_style == "Multi":
        if selected_level == "Pre-Teen American (W/CC/F/Sw)":
            amwaltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/WDSF & Smooth Edits (90BPM)/'
            amwaltzes = [f for f in os.listdir(amwaltz_files) if f.endswith("flac")]
            amwaltz_song = random.choice(amwaltzes)
            amwaltz, sr = librosa.load(os.path.join(amwaltz_files, amwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amwaltz = int(fade_start_point_amwaltz + (fade_duration * sr))
            amwaltz_faded = amwaltz[0:fade_end_point_amwaltz].copy()
            for i in range(fade_start_point_amwaltz,fade_end_point_amwaltz):
                amwaltz_faded[i] = amwaltz[i] * fade_env[i-fade_start_point_amwaltz]
                
            amccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/Rhythm Edits (120BPM)/'
            amcccs = [f for f in os.listdir(amccc_files) if f.endswith("flac")]
            amccc_song = random.choice(amcccs)
            amccc, sr = librosa.load(os.path.join(amccc_files, amccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amccc = int(fade_start_point_amccc + (fade_duration * sr))
            amccc_faded = amccc[0:fade_end_point_amccc].copy()
            for i in range(fade_start_point_amccc,fade_end_point_amccc):
                amccc_faded[i] = amccc[i] * fade_env[i-fade_start_point_amccc]
                
            amfoxtrot_files = 'E:/Music/Incompressible Files/Edits/Smooth Foxtrot/WDSF & Smooth Edits (120BPM)/'
            amfoxtrots = [f for f in os.listdir(amfoxtrot_files) if f.endswith("flac")]
            amfoxtrot_song = random.choice(amfoxtrots)
            amfoxtrot, sr = librosa.load(os.path.join(amfoxtrot_files, amfoxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amfoxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amfoxtrot = int(fade_start_point_amfoxtrot + (fade_duration * sr))
            amfoxtrot_faded = amfoxtrot[0:fade_end_point_amfoxtrot].copy()
            for i in range(fade_start_point_amfoxtrot,fade_end_point_amfoxtrot):
                amfoxtrot_faded[i] = amfoxtrot[i] * fade_env[i-fade_start_point_amfoxtrot]
                
            swing_files = 'E:/Music/Incompressible Files/Edits/Swing/Rhythm Edits (140BPM)/'
            swings = [f for f in os.listdir(swing_files) if f.endswith("flac")]
            swing_song = random.choice(swing)
            swing, sr = librosa.load(os.path.join(swing_files, swing_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_swing = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_swing = int(fade_start_point_swing + (fade_duration * sr))
            swing_faded = swing[0:fade_end_point_swing].copy()
            for i in range(fade_start_point_swing,fade_end_point_swing):
                swing_faded[i] = swing[i] * fade_env[i-fade_start_point_swing]
                
            sd.stop()
            preteen_american = np.concatenate([amwaltz_faded, silence, amccc_faded, silence, amfoxtrot_faded, silence, swing_faded])
            sd.play(preteen_american)
        elif selected_level == "American 9-Dance (W/T/F/VW/CC/R/Sw/B/M)":
            amwaltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/WDSF & Smooth Edits (90BPM)/'
            amwaltzes = [f for f in os.listdir(amwaltz_files) if f.endswith("flac")]
            amwaltz_song = random.choice(amwaltzes)
            amwaltz, sr = librosa.load(os.path.join(amwaltz_files, amwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amwaltz = int(fade_start_point_amwaltz + (fade_duration * sr))
            amwaltz_faded = amwaltz[0:fade_end_point_amwaltz].copy()
            for i in range(fade_start_point_amwaltz,fade_end_point_amwaltz):
                amwaltz_faded[i] = amwaltz[i] * fade_env[i-fade_start_point_amwaltz]
            
            amtango_files = 'E:/Music/Incompressible Files/Edits/Tango/Smooth Edits (120BPM)/'
            amtangos = [f for f in os.listdir(amtango_files) if f.endswith("flac")]
            amtango_song = random.choice(amtangos)
            amtango, sr = librosa.load(os.path.join(amtango_files, amtango_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amtango = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amtango = int(fade_start_point_amtango + (fade_duration * sr))
            amtango_faded = amtango[0:fade_end_point_amtango].copy()
            for i in range(fade_start_point_amtango,fade_end_point_amtango):
                amtango_faded[i] = amtango[i] * fade_env[i-fade_start_point_amtango]
                
            amfoxtrot_files = 'E:/Music/Incompressible Files/Edits/Smooth Foxtrot/WDSF & Smooth Edits (120BPM)/'
            amfoxtrots = [f for f in os.listdir(amfoxtrot_files) if f.endswith("flac")]
            amfoxtrot_song = random.choice(amfoxtrots)
            amfoxtrot, sr = librosa.load(os.path.join(amfoxtrot_files, amfoxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amfoxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amfoxtrot = int(fade_start_point_amfoxtrot + (fade_duration * sr))
            amfoxtrot_faded = amfoxtrot[0:fade_end_point_amfoxtrot].copy()
            for i in range(fade_start_point_amfoxtrot,fade_end_point_amfoxtrot):
                amfoxtrot_faded[i] = amfoxtrot[i] * fade_env[i-fade_start_point_amfoxtrot]
            
            amvwaltz_files = 'E:/Music/Incompressible Files/Edits/Viennese Waltz/Smooth Edits (159BPM)/'
            amvwaltzes = [f for f in os.listdir(amvwaltz_files) if f.endswith("flac")]
            amvwaltz_song = random.choice(amvwaltzes)
            amvwaltz, sr = librosa.load(os.path.join(amvwaltz_files, amvwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amvwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amvwaltz = int(fade_start_point_amvwaltz + (fade_duration * sr))
            amvwaltz_faded = amvwaltz[0:fade_end_point_amvwaltz].copy()
            for i in range(fade_start_point_amvwaltz,fade_end_point_amvwaltz):
                amvwaltz_faded[i] = amvwaltz[i] * fade_env[i-fade_start_point_amvwaltz]
                
            amccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/Rhythm Edits (120BPM)/'
            amcccs = [f for f in os.listdir(amccc_files) if f.endswith("flac")]
            amccc_song = random.choice(amcccs)
            amccc, sr = librosa.load(os.path.join(amccc_files, amccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amccc = int(fade_start_point_amccc + (fade_duration * sr))
            amccc_faded = amccc[0:fade_end_point_amccc].copy()
            for i in range(fade_start_point_amccc,fade_end_point_amccc):
                amccc_faded[i] = amccc[i] * fade_env[i-fade_start_point_amccc]
            
            amrumba_files = 'E:/Music/Incompressible Files/Edits/American Rumba/NDCA Edits (124BPM)/'
            amrumbas = [f for f in os.listdir(amrumba_files) if f.endswith("flac")]
            amrumba_song = random.choice(amrumbas)
            amrumba, sr = librosa.load(os.path.join(amrumba_files, amrumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_amrumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_amrumba = int(fade_start_point_amrumba + (fade_duration * sr))
            amrumba_faded = amrumba[0:fade_end_point_amrumba].copy()
            for i in range(fade_start_point_amrumba,fade_end_point_amrumba):
                amrumba_faded[i] = amrumba[i] * fade_env[i-fade_start_point_amrumba]
                
            swing_files = 'E:/Music/Incompressible Files/Edits/Swing/Rhythm Edits (140BPM)/'
            swings = [f for f in os.listdir(swing_files) if f.endswith("flac")]
            swing_song = random.choice(swing)
            swing, sr = librosa.load(os.path.join(swing_files, swing_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_swing = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_swing = int(fade_start_point_swing + (fade_duration * sr))
            swing_faded = swing[0:fade_end_point_swing].copy()
            for i in range(fade_start_point_swing,fade_end_point_swing):
                swing_faded[i] = swing[i] * fade_env[i-fade_start_point_swing]
                
            bolero_files = 'E:/Music/Incompressible Files/Edits/Bolero/Rhythm Edits (92BPM)/'
            boleros = [f for f in os.listdir(bolero_files) if f.endswith("flac")]
            bolero_song = random.choice(boleros)
            bolero, sr = librosa.load(os.path.join(bolero_files, bolero_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_bolero = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_bolero = int(fade_start_point_bolero + (fade_duration * sr))
            bolero_faded = bolero[0:fade_end_point_bolero].copy()
            for i in range(fade_start_point_bolero,fade_end_point_bolero):
                bolero_faded[i] = bolero[i] * fade_env[i-fade_start_point_bolero]
                
            mambo_files = 'E:/Music/Incompressible Files/Edits/Mambo/Rhythm Edits (188BPM)/'
            mambos = [f for f in os.listdir(mambo_files) if f.endswith("flac")]
            mambo_song = random.choice(mambos)
            mambo, sr = librosa.load(os.path.join(mambo_files, mambo_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_mambo = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_mambo = int(fade_start_point_mambo + (fade_duration * sr))
            mambo_faded = mambo[0:fade_end_point_mambo].copy()
            for i in range(fade_start_point_mambo,fade_end_point_mambo):
                mambo_faded[i] = mambo[i] * fade_env[i-fade_start_point_mambo]
            
            sd.stop()
            american_9dance = np.concatenate([amwaltz_faded, silence, amtango_faded, silence, amfoxtrot_faded, silence, amvwaltz_faded, silence, amccc_faded, silence, amrumba_faded, silence, swing_faded, silence, bolero_faded, silence, mambo_faded])
            sd.play(american_9dance)
        elif selected_level == "International 10-Dance (W/T/VW/F/Q/CC/S/R/PD/J)":
            waltz_files = 'E:/Music/Incompressible Files/Edits/Waltz/NDCA Edits (87BPM)/'
            waltzes = [f for f in os.listdir(waltz_files) if f.endswith("flac")]
            waltz_song = random.choice(waltzes)
            waltz, sr = librosa.load(os.path.join(waltz_files, waltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_waltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_waltz = int(fade_start_point_waltz + (fade_duration * sr))
            waltz_faded = waltz[0:fade_end_point_waltz].copy()
            for i in range(fade_start_point_waltz,fade_end_point_waltz):
                waltz_faded[i] = waltz[i] * fade_env[i-fade_start_point_waltz]
                
            tango_files = 'E:/Music/Incompressible Files/Edits/Tango/NDCA Edits (128BPM)/'
            tangos = [f for f in os.listdir(tango_files) if f.endswith("flac")]
            tango_song = random.choice(tangos)
            tango, sr = librosa.load(os.path.join(tango_files, tango_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_tango = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_tango = int(fade_start_point_tango + (fade_duration * sr))
            tango_faded = tango[0:fade_end_point_tango].copy()
            for i in range(fade_start_point_tango,fade_end_point_tango):
                tango_faded[i] = tango[i] * fade_env[i-fade_start_point_tango]
                
            vwaltz_files = 'E:/Music/Incompressible Files/Edits/Viennese Waltz/NDCA Edits (174BPM)/'
            vwaltzes = [f for f in os.listdir(vwaltz_files) if f.endswith("flac")]
            vwaltz_song = random.choice(vwaltzes)
            vwaltz, sr = librosa.load(os.path.join(vwaltz_files, vwaltz_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_vwaltz = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_vwaltz = int(fade_start_point_vwaltz + (fade_duration * sr))
            vwaltz_faded = vwaltz[0:fade_end_point_vwaltz].copy()
            for i in range(fade_start_point_vwaltz,fade_end_point_vwaltz):
                vwaltz_faded[i] = vwaltz[i] * fade_env[i-fade_start_point_vwaltz]
            sd.play(vwaltz_faded)    
            
            foxtrot_files = 'E:/Music/Incompressible Files/Edits/Std. Foxtrot/NDCA Edits (112BPM)/'
            foxtrots = [f for f in os.listdir(foxtrot_files) if f.endswith("flac")]
            foxtrot_song = random.choice(foxtrots)
            foxtrot, sr = librosa.load(os.path.join(foxtrot_files, foxtrot_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_foxtrot = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_foxtrot = int(fade_start_point_foxtrot + (fade_duration * sr))
            foxtrot_faded = foxtrot[0:fade_end_point_foxtrot].copy()
            for i in range(fade_start_point_foxtrot,fade_end_point_foxtrot):
                foxtrot_faded[i] = foxtrot[i] * fade_env[i-fade_start_point_foxtrot]
            sd.play(foxtrot_faded)
            
            quickstep_files = 'E:/Music/Incompressible Files/Edits/Quickstep/NDCA Edits (200BPM)/'
            quicksteps = [f for f in os.listdir(quickstep_files) if f.endswith("flac")]
            quickstep_song = random.choice(quicksteps)
            quickstep, sr = librosa.load(os.path.join(quickstep_files, quickstep_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_quickstep = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_quickstep = int(fade_start_point_quickstep + (fade_duration * sr))
            quickstep_faded = quickstep[0:fade_end_point_quickstep].copy()
            for i in range(fade_start_point_quickstep,fade_end_point_quickstep):
                quickstep_faded[i] = quickstep[i] * fade_env[i-fade_start_point_quickstep]
                
            ccc_files = 'E:/Music/Incompressible Files/Edits/Cha Cha/NDCA Edits (124BPM)/'
            cccs = [f for f in os.listdir(ccc_files) if f.endswith("flac")]
            ccc_song = random.choice(cccs)
            ccc, sr = librosa.load(os.path.join(ccc_files, ccc_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_ccc = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_ccc = int(fade_start_point_ccc + (fade_duration * sr))
            ccc_faded = ccc[0:fade_end_point_ccc].copy()
            for i in range(fade_start_point_ccc,fade_end_point_ccc):
                ccc_faded[i] = ccc[i] * fade_env[i-fade_start_point_ccc]
                
            samba_files = 'E:/Music/Incompressible Files/Edits/Samba/NDCA Edits (100BPM)/'
            sambas = [f for f in os.listdir(samba_files) if f.endswith("flac")]
            samba_song = random.choice(sambas)
            samba, sr = librosa.load(os.path.join(samba_files, samba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_samba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_samba = int(fade_start_point_samba + (fade_duration * sr))
            samba_faded = samba[0:fade_end_point_samba].copy()
            for i in range(fade_start_point_samba,fade_end_point_samba):
                samba_faded[i] = samba[i] * fade_env[i-fade_start_point_samba]
            
            rumba_files = 'E:/Music/Incompressible Files/Edits/Intl Rumba/NDCA Edits (96BPM)/'
            rumbas = [f for f in os.listdir(rumba_files) if f.endswith("flac")]
            rumba_song = random.choice(rumbas)
            rumba, sr = librosa.load(os.path.join(rumba_files, rumba_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_rumba = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_rumba = int(fade_start_point_rumba + (fade_duration * sr))
            rumba_faded = rumba[0:fade_end_point_rumba].copy()
            for i in range(fade_start_point_rumba,fade_end_point_rumba):
                rumba_faded[i] = rumba[i] * fade_env[i-fade_start_point_rumba]
                
            paso_files = 'E:/Music/Incompressible Files/Edits/Paso Doble/2-Phrased/NDCA Edits (110BPM)/'
            pasos = [f for f in os.listdir(paso_files) if f.endswith("flac")]
            paso_song = random.choice(pasos)
            paso2, sr = librosa.load(os.path.join(paso_files, paso_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            
            jive_files = 'E:/Music/Incompressible Files/Edits/Jive/NDCA Edits (172BPM)/'
            jives = [f for f in os.listdir(jive_files) if f.endswith("flac")]
            jive_song = random.choice(jives)
            jive, sr = librosa.load(os.path.join(jive_files, jive_song), sr=None)
            fade_duration = 10
            fade_samples = int(fade_duration * sr)
            fade_env = np.linspace(1, 0, fade_samples)
            fade_start_point_jive = int((random.randint(72000,87000)/1000) * sr)
            fade_end_point_jive = int(fade_start_point_jive + (fade_duration * sr))
            jive_faded = jive[0:fade_end_point_jive].copy()
            for i in range(fade_start_point_jive,fade_end_point_jive):
                jive_faded[i] = jive[i] * fade_env[i-fade_start_point_jive]
            
            sd.stop()
            international_10dance = np.concatenate([waltz_faded, silence, tango_faded, silence, vwaltz_faded, silence, foxtrot_faded, silence, quickstep_faded, silence, ccc_faded, silence, samba_faded, silence, rumba_faded, silence, paso2, silence, jive_faded])
            sd.play(international_10dance)
            
    pass

the_button = tk.Button(program, text='Create Round', command=create_round)
the_button.configure(width=50, height=2)
the_button.grid(row=5, column=1, columnspan=2)

# %%
program.mainloop()

# %%
sd.stop()
